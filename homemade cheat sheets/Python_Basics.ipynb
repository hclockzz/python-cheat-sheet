# %% [markdown]
# # Python IO

# %% [markdown]
# ## argparse
# - basic usage
# - subcommand

# %%
import argparse

"""
command line execution result:

ip-192-168-2-12:my-code-base hongshengzhong$ python learn-argparse.py foo 73
usage: learn-argparse.py [-h] foo
learn-argparse.py: error: argument foo: invalid int value: 'foo'

ip-192-168-2-12:my-code-base hongshengzhong$ python learn-argparse.py 73
73
"""

parser = argparse.ArgumentParser()
parser.add_argument('foo', type=int)
parser.set_defaults(bar=42, baz='badger')
# parser.parse_args(['736'])
args = parser.parse_args()
print(args.foo)

# %%
"""
command line execution result:

ip-192-168-2-12:my-code-base hongshengzhong$ python learn-argparse.py --foo 73
73
"""

parser = argparse.ArgumentParser()
parser.add_argument('--foo', type=int)   # changes are here
parser.set_defaults(bar=42, baz='badger')
# parser.parse_args(['736'])
args = parser.parse_args()
print(args.foo)

# %%
# Out:
# _StoreAction(option_strings=['--baz'], dest='baz', nargs=None, const=None, default=None, type=None, choices='XYZ', help='baz help', metavar=None)

# %% [markdown]
# ## MongoDB Shell

# %% [markdown]
# ### Queries

# %%
{"cde.type":"roundup", "raw.blocks.0.posts":{$elemMatch:{"permalink":{$exists:false}}}}

/** 
* Paste one or more documents here
*/
{
    "pipeline_id": "https://www.seriouseats.com/roundups/best-knife-sharpeners",
    "at": "2021-03-19T19:45:05Z",
    "cde": {
        "type": "roundup"
    },
    "legacy_url": "https://www.seriouseats.com/roundups/best-knife-sharpeners",
    "raw": {
        "title": "The Best Tools for Sharpening Your Knives",
        "kicker": "Everything you need to keep your knives sharp at home. ",
        "body": "<p><img src=\"https://www.seriouseats.com/2018/06/20180606-chef-knives-tests-vicky-wasik-18-1500x1125.jpg\" alt=\"Knives lined up on white background.\" /></p>\n<p>We’ve spent a lot of time at Serious Eats figuring out which <a href=\"https://www.seriouseats.com/2019/04/the-best-essential-knives.html\">knives are the most useful and necessary</a>. We’ve tested countless knives of all shapes, sizes, and prices, and we’ve shown you have to use them properly in our <a href=\"https://www.seriouseats.com/how-tos/cooking-techniques/knife-skills\">knife skills videos</a>. But it doesn’t matter how fancy or expensive or highly regarded by knife nerds your knives are if they aren’t sharp. Dull knives are worthless; even worse, they’re dangerous. </p>\n<p>Below you’ll find all the equipment our culinary team relies on to keep their knives sharp. Some require more skill to use than others. All of them will help preserve your knives and keep your fingers safe as you work your way through our recipes. </p>\n<p>One last thing: It would be a waste for you to sharpen your knives, then toss them into a drawer to rub up against other equipment and get all dull again. So store them correctly! You can find our preferred <a href=\"https://www.seriouseats.com/2018/07/how-to-store-knives.html\">knife-storage recommendations here</a>. </p>\n",
        "blocks": [{
            "title": "",
            "posts": [{
                "title": "Electric Sharpener",
                "permalink": "",
                "caption": "",
                "link_text": "",
                "body": "<p>Generally speaking, we don’t recommend electric knife sharpeners because most of them tend to strip off too much metal from your blades. But there's one electric sharpener we can happily get behind: the <dorado id=\"work-sharp-ken-onion-knife-sharpener\" class=\"text\">Ken Onion Sharpener by Worksharp</dorado>. This model offers a series of bands at different grit levels (from coarse to very fine) that allow you to do everything from major knife repair to small finishing work. </p>\n<p>The Ken Onion also allows you to choose the type of blade geometry for whatever implement you're sharpening and has angle guides to ensure the edge is sharpened at the correct angle This way, you can go with whichever edge profile you prefer, whether it’s symmetrical or asymmetrical, and sharpen it consistently every time without having to rely on the muscle memory that you’d need for a whetstone (which can be a major barrier for entry for people new to knife-sharpening). Better yet: Because of the angle options, the sharpener can be used on all sorts of blades, including ax heads, mower blades, and pocket knives. </p>\n<p>If you’re concerned about the price, think about it this way: After a couple of years, it will pay for itself in sharpening fees.</p>\n<p><dorado id=\"work-sharp-ken-onion-knife-sharpener\" /></p>\n",
                "video_id": ""
            }, {
                "body": "<p>The best way to sharpen your knives is to <a href=\"https://www.seriouseats.com/2010/04/knife-skills-how-to-sharpen-a-knife.html\">use a whetstone</a>. Using a whetstone is much more affordable than sending your knives out for professional sharpening, and unlike most electric sharpeners, using a whetstone will shave far less metal off your precious knives. </p>\n<p>Whetstones (or waterstones) come in a variety of grit levels, but we recommend picking up a medium grit stone and a fine grit stone, which is more than sufficient for keeping your knives plenty sharp. Learning how to use them takes a little time and some practice. You can read all about the <a href=\"https://www.seriouseats.com/2010/04/knife-skills-how-to-sharpen-a-knife.html\">technique for using whetstones right here</a>. </p>\n<p><dorado id=\"medium-grit-whetstone,fine-grit-whetstone\" /></p>\n<p>If you pick up a couple of whetstones, you'll want to also pick up a flattening stone (or a stone \"fixer\"), which you can run over your whetstones to get rid of any grooves or unevenness on the stones' surfaces.</p>\n<p><dorado id=\"flattening-stone-for-whestones\" /></p>\n",
                "link_text": "",
                "caption": "[Photo: Vicky Wasik]",
                "permalink": "",
                "video_id": "",
                "title": "Whetstones",
                "image": {
                    "featured": false,
                    "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik.jpg",
                    "title": "20200220-knife-sharpening-whetstone-vicky-wasik",
                    "height": 1125,
                    "description": "",
                    "id": 452237,
                    "sizes": {
                        "small": {
                            "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-300x225.jpg",
                            "height": 225,
                            "width": 300
                        },
                        "medium": {
                            "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-625x469.jpg",
                            "width": 625,
                            "height": 469
                        },
                        "thumbnail": {
                            "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-200x150.jpg",
                            "height": 150,
                            "width": 200
                        },
                        "medium_large": {
                            "width": 750,
                            "height": 563,
                            "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-750x563.jpg"
                        }
                    },
                    "width": 1500
                }
            }, {
                "video_id": "",
                "caption": "",
                "permalink": "",
                "link_text": "",
                "body": "<p>The technique for using a whetstone can be complicated for beginners. It can also be pretty messy! That’s why our team recommends using a sink bridge: it anchors the whetstone securely, preventing it from moving around as you sharpen, and positions it over your sink so the mess can be easily contained.</p>\n<p><dorado id=\"sharpening-stone-sink-bridge\" /></p>\n",
                "title": "Sink Bridge"
            }, {
                "title": "Angle Guides",
                "image": {
                    "id": 454338,
                    "sizes": {
                        "thumbnail": {
                            "height": 150,
                            "width": 200,
                            "url": "https://www.seriouseats.com/2020/08/20200812-Knife-Sharpening-Angle-Guides-daniel-gritzer-2-200x150.jpg"
                        },
                        "medium_large": {
                            "url": "https://www.seriouseats.com/2020/08/20200812-Knife-Sharpening-Angle-Guides-daniel-gritzer-2-750x563.jpg",
                            "height": 563,
                            "width": 750
                        },
                        "small": {
                            "width": 300,
                            "height": 225,
                            "url": "https://www.seriouseats.com/2020/08/20200812-Knife-Sharpening-Angle-Guides-daniel-gritzer-2-300x225.jpg"
                        },
                        "medium": {
                            "height": 469,
                            "width": 625,
                            "url": "https://www.seriouseats.com/2020/08/20200812-Knife-Sharpening-Angle-Guides-daniel-gritzer-2-625x469.jpg"
                        }
                    },
                    "width": 1500,
                    "featured": false,
                    "url": "https://www.seriouseats.com/2020/08/20200812-Knife-Sharpening-Angle-Guides-daniel-gritzer-2.jpg",
                    "title": "20200812-Knife- Sharpening-Angle-Guides-daniel-gritzer-2",
                    "height": 1125,
                    "description": ""
                },
                "link_text": "",
                "body": "<p>Last year Daniel wrote about his favorite knife-sharpening accessory, <a href=\"https://www.seriouseats.com/2020/08/knife-sharpening-angle-guide.html\">the angle guide</a>, a tiny (and very affordable) accessory that makes it much easier to maintain a consistent angle as you sharpen with a whetstone. Without one, you’re relying solely on muscle memory&mdash;and that can be tough, even for experienced chefs. </p>\n<p>This little kit comes with a variety of angle options. Simply attach one or two (you can stack them!) to your whetstone with a rubber band. They’ll act as a guide as you sharpen, so you don’t need to discern what a 20-degree angle looks like for 10 minutes straight.  </p>\n<p><dorado id=\"angle-guides\" /></p>\n",
                "caption": "[Photograph: Daniel Gritzer]",
                "permalink": "",
                "video_id": ""
            }, {
                "body": "<p>Once you’ve sharpened your blade, you’ll need to hone it. Not sure what the difference is? Sharpening will remove tiny fibers to create a brand new edge; honing ensures the edge is straight. You’ll need to do both if you want a sharp and safe knife. You can see <a href=\"https://www.seriouseats.com/2010/04/knife-skills-how-to-hone-a-dull-knife.html\">Kenji’s technique for knife-honing right here</a>. You can repeat this process any time you use your knives. Though once you notice that honing isn't helping, it's time to bring out your sharpener. </p>\n<p>But which honing steel should you choose? </p>\n<p>In his <a href=\"https://www.seriouseats.com/2016/09/how-to-choose-knife-honing-steel.html\">review of the best honing steels</a>, Daniel outlines three different types: stainless steel, ceramic, and diamond steels. Whichever one you choose, consider the length. The longer the steel, the more space you have to pull your knife along without hitting your workstation. As long as your knives aren't longer than 10 inches, a 12-inch steel should serve you well. </p>\n<p>Stainless steel steels are the most common. For its comfort and price, the 12-inch Winware is Daniel's favorite. An added bonus of metal honing steels is that they're magnetic, so they can hold on to those microscopic metal shards as you hone. That means less cleanup and far less chance of those shards getting into your food! </p>\n<p><dorado id=\"stainless-steel-honing-steel\" /></p>\n<p>Then you have ceramic and diamond steels, which have potential benefits and drawbacks depending on how diligent you are about taking care of your knives. Since they're both more abrasive, they can actually remove more metal from your knife than steels made from stainless steel. That's great if you wait a long time between sharpening sessions, but it isn't so great if you plan on steeling your knife every day. If you find yourself reaching for your honing steel often, it's best if you stick to stainless steel. </p>\n<p><dorado id=\"ceramic-honing-steel,diamond-honing-steel\" /></p>\n",
                "link_text": "",
                "caption": "",
                "permalink": "",
                "video_id": "",
                "title": "Honing Steels"
            }]
        }],
        "allow_comments": true,
        "categories": [{
            "name": "Buying Guides",
            "description": "Whether you're outfitting a new kitchen from scratch or scouting out holiday gifts for food lovers, let these curated equipment lists be your guide.",
            "title": "",
            "url": "https://www.seriouseats.com/products/buying-guides",
            "slug": "buying-guides",
            "column": false,
            "id": 37403,
            "count": 119,
            "breadcrumb": {
                "name": "Product Recs",
                "slug": "products",
                "breadcrumb": {
                    "name": "Serious Eats",
                    "slug": "seriouseats",
                    "url": "https://www.seriouseats.com"
                },
                "url": "https://www.seriouseats.com/products"
            }
        }, {
            "name": "Editors' Picks",
            "description": "Our team dishes on the pieces of equipment they've come to love and rely on most.",
            "title": "",
            "slug": "editors-picks",
            "column": false,
            "url": "https://www.seriouseats.com/products/editors-picks",
            "count": 123,
            "breadcrumb": {
                "url": "https://www.seriouseats.com/products",
                "breadcrumb": {
                    "name": "Serious Eats",
                    "url": "https://www.seriouseats.com",
                    "slug": "seriouseats"
                },
                "slug": "products",
                "name": "Product Recs"
            },
            "id": 37404
        }],
        "legacy": false,
        "tags": ["__dorado", "__featured"],
        "record_type": "roundup",
        "canonical": "",
        "short_title": "",
        "popularity_score": "2.74",
        "noindex": false,
        "comment_count": "17",
        "authored_on": "20210226130009",
        "footer": "",
        "social_images": [{
            "id": 457385,
            "sizes": {
                "small": {
                    "width": 300,
                    "height": 630,
                    "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin-300x630.jpg"
                },
                "thumbnail": {
                    "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin-200x420.jpg",
                    "height": 420,
                    "width": 200
                }
            },
            "width": 600,
            "featured": false,
            "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin.jpg",
            "description": "",
            "title": "knife-sharpening-pin",
            "height": 1260
        }],
        "permalink": "https://www.seriouseats.com/roundups/best-knife-sharpeners",
        "primary_video": {
            "id": "",
            "playlist": false
        },
        "venues": "",
        "linked_posts": [],
        "author_id": 7,
        "headnote": "Everything you need to keep your knives sharp at home. ",
        "excerpt": "Everything you need to keep your knives sharp at home. ",
        "modified_on": "20210226141415",
        "assets": [{
            "width": 600,
            "sizes": {
                "small": {
                    "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin-300x630.jpg",
                    "width": 300,
                    "height": 630
                },
                "thumbnail": {
                    "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin-200x420.jpg",
                    "width": 200,
                    "height": 420
                }
            },
            "id": 457385,
            "title": "knife-sharpening-pin",
            "description": "",
            "height": 1260,
            "url": "https://www.seriouseats.com/2021/02/knife-sharpening-pin.jpg",
            "featured": false
        }, {
            "width": 1500,
            "id": 452237,
            "sizes": {
                "small": {
                    "height": 225,
                    "width": 300,
                    "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-300x225.jpg"
                },
                "medium": {
                    "width": 625,
                    "height": 469,
                    "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-625x469.jpg"
                },
                "medium_large": {
                    "height": 563,
                    "width": 750,
                    "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-750x563.jpg"
                },
                "thumbnail": {
                    "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik-200x150.jpg",
                    "width": 200,
                    "height": 150
                }
            },
            "description": "",
            "height": 1125,
            "title": "20200220-knife-sharpening-whetstone-vicky-wasik",
            "featured": true,
            "url": "https://www.seriouseats.com/2010/04/20200220-knife-sharpening-whetstone-vicky-wasik.jpg"
        }],
        "entrytopics": "",
        "gallery": false,
        "toc": true,
        "title_tag": "The Best Knife Sharpeners of 2021",
        "id": 456819,
        "author_name": "Ariel Kanter"
    },
    "src_id": 456819,
    "estimated_traffic": -1,
    "selected_for_migration": true
}
